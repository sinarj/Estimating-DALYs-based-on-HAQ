# %% [markdown]
# # Notebook to create the HAQ input data for all the most detailed locations for age specific version

# %%
import pandas as pd
import numpy as np
import pickle as pkl
import copy
import matplotlib.pyplot as plt
from db_queries import get_location_metadata
# %matplotlib inline

# %%
haq_data_dir = '/share/scratch/projects/hssa/haq/HAQ_2017/vanilla_cc_89_paf_242/draws/'
my_data_dir = '/share/scratch/projects/hssa/haq/HAQ_2017/haq_US/'
prog_dir = '/homes/arjuns13/haq/haq/risk_standardized_amen_mort/'
my_data_dir_cancer = '/share/scratch/projects/hssa/haq/HAQ_2017/haq_2017_latest_cancer/cancers_all_most_det_locs/'
years = [2016]#[1990, 1995, 2000, 2005, 2010, 2015, 2016, 2017]

# %% [markdown]
# ### Location -filtering 195 coutries. HAQ min-max calculations are indeed supposed to be done using all of the 195 countries

# %%
locsdf = get_location_metadata(gbd_round_id=5, location_set_id=35)
causelist = pd.read_csv(prog_dir+'amenable_cause_list_GBD.csv')

# %%
most_det_locs = locsdf[locsdf['most_detailed']==1]

# %%
most_det_locs = most_det_locs['location_id']

# %%
causelist.shape
# Out:
# (32, 8)

# %%
consolidated_limits  = {
    297:{'age_start':4,
        'age_end':19},
    302:{'age_start':2,
        'age_end':7},
    322:{'age_start':2,
        'age_end':19},
    328:{'age_start':2,
        'age_end':19},
    338:{'age_start':4,
        'age_end':16},
    339:{'age_start':4,
        'age_end':7},
    340:{'age_start':2,
        'age_end':19},
    341:{'age_start':5,
        'age_end':7},
    366:{'age_start':7,
        'age_end':15},
    380:{'age_start':2,
        'age_end':5},
    849:{'age_start':8,
        'age_end':19},
    429:{'age_start':8,
        'age_end':19},
    432:{'age_start':8,
        'age_end':19},
    435:{'age_start':8,
        'age_end':13},
    441:{'age_start':8,
        'age_end':19},
    468:{'age_start':8,
        'age_end':19},
    484:{'age_start':4,
        'age_end':19},
    487:{'age_start':4,
        'age_end':13},
    492:{'age_start':5,
        'age_end':19},
    493:{'age_start':4,
        'age_end':19},
    494:{'age_start':2,
        'age_end':19},
    498:{'age_start':4,
        'age_end':19},
    508:{'age_start':5,
        'age_end':7},
    527:{'age_start':5,
        'age_end':19},
    529:{'age_start':5,
        'age_end':19},
    531:{'age_start':5,
        'age_end':19},
    534:{'age_start':5,
        'age_end':19},
    545:{'age_start':4,
        'age_end':19},
    587:{'age_start':2,
        'age_end':14},
    589:{'age_start':4,
        'age_end':19},
    643:{'age_start':2,
        'age_end':18},
    708:{'age_start':2,
        'age_end':19}
}
cause_limits = pd.DataFrame(consolidated_limits) 
cause_limits = cause_limits.T.reset_index()
cause_limits = cause_limits.rename(index=str, columns={'index':'cause_id'})

# %%
len(consolidated_limits)
# Out:
# 32

# %% [markdown]
# ### Combined data - for all most detailed locations

# %%
allMostDet_data_noncancer =[]

for y in years:
    print('Processing: ',y)
    for i in list(most_det_locs):
        print('Processing loc: ',i)
        df = pd.read_csv(my_data_dir+'std_all_most_det_locs/'+str(y)+'/'+str(i)+'.csv')
        # dropping cancer
        df = df[~df['cause_id'].isin([849, 429, 432, 435, 441, 468, 484, 487])]
        
        df = df.merge(cause_limits,on='cause_id')
        df = df[(df['age_group_id'] >= df['age_start'])&(df['age_group_id'] <= df['age_end'])]
        df = df.drop(['age_end','age_start'],axis=1)
        
        allMostDet_data_noncancer.append(df)
allMostDet_data_noncancer = pd.concat(allMostDet_data_noncancer, axis=0)

print("Saving to ", my_data_dir+'combined_data/global_data/')
allMostDet_data_noncancer.to_csv(my_data_dir+'combined_data/global_data/' + 'allMostDet_data_noncancer.csv',index=False)
# Out:
# Processing:  2016
# Processing loc:  33
# Processing loc:  34
# Processing loc:  35
# Processing loc:  36
# Processing loc:  37
# Processing loc:  38
# Processing loc:  39
# Processing loc:  40
# Processing loc:  41
# Processing loc:  43
# Processing loc:  44
# Processing loc:  45
# Processing loc:  46
# Processing loc:  47
# Processing loc:  48
# Processing loc:  49
# Processing loc:  50
# Processing loc:  51
# Processing loc:  52
# Processing loc:  53
# Processing loc:  54
# Processing loc:  55
# Processing loc:  57
# Processing loc:  58
# Processing loc:  59
# Processing loc:  60
# Processing loc:  61
# Processing loc:  44971
# Processing loc:  44983
# Processing loc:  44924
# Processing loc:  44936
# Processing loc:  44903
# Processing loc:  44904
# Processing loc:  44945
# Processing loc:  44966
# Processing loc:  44987
# Processing loc:  44952
# Processing loc:  44974
# Processing loc:  44907
# Processing loc:  44986
# Processing loc:  44942
# Processing loc:  44926
# Processing loc:  44908
# Processing loc:  44980
# Processing loc:  44943
# Processing loc:  44975
# Processing loc:  44982
# Processing loc:  44963
# Processing loc:  44954
# Processing loc:  44922
# Processing loc:  44909
# Processing loc:  44935
# Processing loc:  44973
# Processing loc:  44961
# Processing loc:  44910
# Processing loc:  44927
# Processing loc:  44911
# Processing loc:  44984
# Processing loc:  44920
# Processing loc:  44912
# Processing loc:  44928
# Processing loc:  44923
# Processing loc:  44955
# Processing loc:  44929
# Processing loc:  44976
# Processing loc:  44977
# Processing loc:  44956
# Processing loc:  44913
# Processing loc:  44957
# Processing loc:  44953
# Processing loc:  44981
# Processing loc:  44930
# Processing loc:  44932
# Processing loc:  44967
# Processing loc:  44947
# Processing loc:  44968
# Processing loc:  44940
# Processing loc:  44941
# Processing loc:  44933
# Processing loc:  44921
# Processing loc:  44970
# Processing loc:  44948
# Processing loc:  44949
# Processing loc:  44944
# Processing loc:  44979
# Processing loc:  44950
# Processing loc:  44969
# Processing loc:  44938
# Processing loc:  44914
# Processing loc:  44985
# Processing loc:  44958
# Processing loc:  44931
# Processing loc:  44959
# Processing loc:  44915
# Processing loc:  44946
# Processing loc:  44962
# Processing loc:  44916
# Processing loc:  44978
# Processing loc:  44918
# Processing loc:  44917
# Processing loc:  44965
# Processing loc:  44951
# Processing loc:  44960
# Processing loc:  44905
# Processing loc:  44937
# Processing loc:  44925
# Processing loc:  44906
# Processing loc:  44964
# Processing loc:  44919
# Processing loc:  44972
# Processing loc:  44934
# Processing loc:  44939
# Processing loc:  50559
# Processing loc:  71
# Processing loc:  44850
# Processing loc:  44851
# Processing loc:  66
# Processing loc:  35446
# Processing loc:  35428
# Processing loc:  35425
# Processing loc:  35435
# Processing loc:  35461
# Processing loc:  35441
# Processing loc:  35463
# Processing loc:  35430
# Processing loc:  35444
# Processing loc:  35433
# Processing loc:  35457
# Processing loc:  35424
# Processing loc:  35451
# Processing loc:  35431
# Processing loc:  35440
# Processing loc:  35426
# Processing loc:  35460
# Processing loc:  35469
# Processing loc:  35437
# Processing loc:  35462
# Processing loc:  35466
# Processing loc:  35449
# Processing loc:  35447
# Processing loc:  35427
# Processing loc:  35468
# Processing loc:  35443
# Processing loc:  35465
# Processing loc:  35452
# Processing loc:  35438
# Processing loc:  35467
# Processing loc:  35456
# Processing loc:  35470
# Processing loc:  35450
# Processing loc:  35464
# Processing loc:  35434
# Processing loc:  35448
# Processing loc:  35455
# Processing loc:  35445
# Processing loc:  35432
# Processing loc:  35459
# Processing loc:  35436
# Processing loc:  35454
# Processing loc:  35439
# Processing loc:  35453
# Processing loc:  35429
# Processing loc:  35458
# Processing loc:  35442
# Processing loc:  68
# Processing loc:  69
# Processing loc:  101
# Processing loc:  349
# Processing loc:  523
# Processing loc:  524
# Processing loc:  525
# Processing loc:  526
# Processing loc:  527
# Processing loc:  528
# Processing loc:  529
# Processing loc:  530
# Processing loc:  531
# Processing loc:  532
# Processing loc:  533
# Processing loc:  534
# Processing loc:  535
# Processing loc:  536
# Processing loc:  537
# Processing loc:  538
# Processing loc:  539
# Processing loc:  540
# Processing loc:  541
# Processing loc:  542
# Processing loc:  543
# Processing loc:  544
# Processing loc:  545
# Processing loc:  546
# Processing loc:  547
# Processing loc:  548
# Processing loc:  549
# Processing loc:  550
# Processing loc:  551
# Processing loc:  552
# Processing loc:  553
# Processing loc:  554
# Processing loc:  555
# Processing loc:  556
# Processing loc:  557
# Processing loc:  558
# Processing loc:  559
# Processing loc:  560
# Processing loc:  561
# Processing loc:  562
# Processing loc:  563
# Processing loc:  564
# Processing loc:  565
# Processing loc:  566
# Processing loc:  567
# Processing loc:  568
# Processing loc:  569
# Processing loc:  570
# Processing loc:  571
# Processing loc:  572
# Processing loc:  573
# Processing loc:  97
# Processing loc:  98
# Processing loc:  99
# Processing loc:  74
# Processing loc:  75
# Processing loc:  76
# Processing loc:  77
# Processing loc:  78
# Processing loc:  79
# Processing loc:  80
# Processing loc:  81
# Processing loc:  82
# Processing loc:  83
# Processing loc:  84
# Processing loc:  85
# Processing loc:  86
# Processing loc:  87
# Processing loc:  88
# Processing loc:  89
# Processing loc:  4914
# Processing loc:  4911
# Processing loc:  4918
# Processing loc:  4915
# Processing loc:  4928
# Processing loc:  4912
# Processing loc:  4921
# Processing loc:  4923
# Processing loc:  4926
# Processing loc:  4913
# Processing loc:  4910
# Processing loc:  4920
# Processing loc:  4922
# Processing loc:  4917
# Processing loc:  53432
# Processing loc:  4927
# Processing loc:  4919
# Processing loc:  4916
# Processing loc:  91
# Processing loc:  92
# Processing loc:  4944
# Processing loc:  4940
# Processing loc:  94
# Processing loc:  44697
# Processing loc:  44698
# Processing loc:  44701
# Processing loc:  44694
# Processing loc:  44695
# Processing loc:  44693
# Processing loc:  44700
# Processing loc:  44699
# Processing loc:  44696
# Processing loc:  44716
# Processing loc:  44721
# Processing loc:  44717
# Processing loc:  44720
# Processing loc:  44719
# Processing loc:  44726
# Processing loc:  44723
# Processing loc:  44725
# Processing loc:  44724
# Processing loc:  44718
# Processing loc:  44722
# Processing loc:  44754
# Processing loc:  44729
# Processing loc:  44732
# Processing loc:  44735
# Processing loc:  44731
# Processing loc:  44748
# Processing loc:  44742
# Processing loc:  44744
# Processing loc:  44741
# Processing loc:  44745
# Processing loc:  44756
# Processing loc:  44743
# Processing loc:  44755
# Processing loc:  44740
# Processing loc:  44737
# Processing loc:  44736
# Processing loc:  44751
# Processing loc:  44757
# Processing loc:  44728
# Processing loc:  44738
# Processing loc:  44749
# Processing loc:  44750
# Processing loc:  44734
# Processing loc:  44753
# Processing loc:  44733
# Processing loc:  44727
# Processing loc:  44752
# Processing loc:  44739
# Processing loc:  44758
# Processing loc:  44747
# Processing loc:  44746
# Processing loc:  44730
# Processing loc:  44649
# Processing loc:  44643
# Processing loc:  44650
# Processing loc:  44654
# Processing loc:  44651
# Processing loc:  44646
# Processing loc:  44647
# Processing loc:  44644
# Processing loc:  44648
# Processing loc:  44652
# Processing loc:  44645
# Processing loc:  44653
# Processing loc:  44674
# Processing loc:  44676
# Processing loc:  44662
# Processing loc:  44664
# Processing loc:  44655
# Processing loc:  44658
# Processing loc:  44661
# Processing loc:  44670
# Processing loc:  44675
# Processing loc:  44660
# Processing loc:  44671
# Processing loc:  44677
# Processing loc:  44667
# Processing loc:  44668
# Processing loc:  44673
# Processing loc:  44659
# Processing loc:  44665
# Processing loc:  44656
# Processing loc:  44672
# Processing loc:  44657
# Processing loc:  44666
# Processing loc:  44669
# Processing loc:  44663
# Processing loc:  44765
# Processing loc:  44770
# Processing loc:  44760
# Processing loc:  44772
# Processing loc:  44764
# Processing loc:  44774
# Processing loc:  44769
# Processing loc:  44771
# Processing loc:  44775
# Processing loc:  44767
# Processing loc:  44773
# Processing loc:  44768
# Processing loc:  44777
# Processing loc:  44776
# Processing loc:  44761
# Processing loc:  44763
# Processing loc:  44766
# Processing loc:  44762
# Processing loc:  44759
# Processing loc:  44784
# Processing loc:  44790
# Processing loc:  44789
# Processing loc:  44791
# Processing loc:  44782
# Processing loc:  44779
# Processing loc:  44785
# Processing loc:  44781
# Processing loc:  44792
# Processing loc:  44783
# Processing loc:  44786
# Processing loc:  44778
# Processing loc:  44787
# Processing loc:  44788
# Processing loc:  44780
# Processing loc:  44714
# Processing loc:  44709
# Processing loc:  44708
# Processing loc:  44703
# Processing loc:  44715
# Processing loc:  44705
# Processing loc:  44704
# Processing loc:  44707
# Processing loc:  44711
# Processing loc:  44710
# Processing loc:  44712
# Processing loc:  44702
# Processing loc:  44713
# Processing loc:  44706
# Processing loc:  44692
# Processing loc:  44684
# Processing loc:  44682
# Processing loc:  44690
# Processing loc:  44679
# Processing loc:  44691
# Processing loc:  44685
# Processing loc:  44686
# Processing loc:  44681
# Processing loc:  44683
# Processing loc:  44678
# Processing loc:  44689
# Processing loc:  44687
# Processing loc:  44688
# Processing loc:  44680
# Processing loc:  433
# Processing loc:  434
# Processing loc:  4636
# Processing loc:  121
# Processing loc:  122
# Processing loc:  123
# Processing loc:  105
# Processing loc:  106
# Processing loc:  107
# Processing loc:  108
# Processing loc:  305
# Processing loc:  109
# Processing loc:  110
# Processing loc:  111
# Processing loc:  112
# Processing loc:  113
# Processing loc:  114
# Processing loc:  115
# Processing loc:  385
# Processing loc:  116
# Processing loc:  117
# Processing loc:  118
# Processing loc:  119
# Processing loc:  422
# Processing loc:  125
# Processing loc:  126
# Processing loc:  127
# Processing loc:  128
# Processing loc:  129
# Processing loc:  4643
# Processing loc:  4644
# Processing loc:  4645
# Processing loc:  4646
# Processing loc:  4649
# Processing loc:  4650
# Processing loc:  4647
# Processing loc:  4648
# Processing loc:  4652
# Processing loc:  4653
# Processing loc:  4654
# Processing loc:  4655
# Processing loc:  4656
# Processing loc:  4657
# Processing loc:  4651
# Processing loc:  4658
# Processing loc:  4659
# Processing loc:  4660
# Processing loc:  4661
# Processing loc:  4662
# Processing loc:  4663
# Processing loc:  4664
# Processing loc:  4665
# Processing loc:  4666
# Processing loc:  4667
# Processing loc:  4668
# Processing loc:  4669
# Processing loc:  4670
# Processing loc:  4671
# Processing loc:  4672
# Processing loc:  4673
# Processing loc:  4674
# Processing loc:  131
# Processing loc:  132
# Processing loc:  133
# Processing loc:  4750
# Processing loc:  4751
# Processing loc:  4753
# Processing loc:  4752
# Processing loc:  4754
# Processing loc:  4755
# Processing loc:  4756
# Processing loc:  4757
# Processing loc:  4758
# Processing loc:  4759
# Processing loc:  4762
# Processing loc:  4761
# Processing loc:  4760
# Processing loc:  4763
# Processing loc:  4764
# Processing loc:  4765
# Processing loc:  4766
# Processing loc:  4767
# Processing loc:  4768
# Processing loc:  4769
# Processing loc:  4772
# Processing loc:  4770
# Processing loc:  4771
# Processing loc:  4773
# Processing loc:  4775
# Processing loc:  4774
# Processing loc:  4776
# Processing loc:  136
# Processing loc:  160
# Processing loc:  139
# Processing loc:  140
# Processing loc:  141
# Processing loc:  44864
# Processing loc:  44865
# Processing loc:  44868
# Processing loc:  44869
# Processing loc:  44866
# Processing loc:  44870
# Processing loc:  44871
# Processing loc:  44872
# Processing loc:  44873
# Processing loc:  44874
# Processing loc:  44875
# Processing loc:  44876
# Processing loc:  44877
# Processing loc:  44878
# Processing loc:  44880
# Processing loc:  44882
# Processing loc:  44883
# Processing loc:  44884
# Processing loc:  44885
# Processing loc:  44886
# Processing loc:  44887
# Processing loc:  44879
# Processing loc:  44888
# Processing loc:  44889
# Processing loc:  44890
# Processing loc:  44891
# Processing loc:  44881
# Processing loc:  44892
# Processing loc:  44867
# Processing loc:  44893
# Processing loc:  44894
# Processing loc:  143
# Processing loc:  144
# Processing loc:  145
# Processing loc:  146
# Processing loc:  147
# Processing loc:  148
# Processing loc:  149
# Processing loc:  150
# Processing loc:  151
# Processing loc:  152
# Processing loc:  522
# Processing loc:  153
# Processing loc:  154
# Processing loc:  155
# Processing loc:  156
# Processing loc:  157
# Processing loc:  161
# Processing loc:  162
# Processing loc:  43908
# Processing loc:  43872
# Processing loc:  43909
# Processing loc:  43873
# Processing loc:  43910
# Processing loc:  43874
# Processing loc:  43911
# Processing loc:  43875
# Processing loc:  43913
# Processing loc:  43877
# Processing loc:  43916
# Processing loc:  43880
# Processing loc:  43917
# Processing loc:  43881
# Processing loc:  43918
# Processing loc:  43882
# Processing loc:  43919
# Processing loc:  43883
# Processing loc:  43920
# Processing loc:  43884
# Processing loc:  43921
# Processing loc:  43885
# Processing loc:  43922
# Processing loc:  43886
# Processing loc:  43923
# Processing loc:  43887
# Processing loc:  43924
# Processing loc:  43888
# Processing loc:  43926
# Processing loc:  43890
# Processing loc:  43927
# Processing loc:  43891
# Processing loc:  43928
# Processing loc:  43892
# Processing loc:  43929
# Processing loc:  43893
# Processing loc:  43930
# Processing loc:  43894
# Processing loc:  43931
# Processing loc:  43895
# Processing loc:  43932
# Processing loc:  43896
# Processing loc:  43934
# Processing loc:  43898
# Processing loc:  43935
# Processing loc:  43899
# Processing loc:  43936
# Processing loc:  43900
# Processing loc:  43937
# Processing loc:  43901
# Processing loc:  43938
# Processing loc:  43902
# Processing loc:  43939
# Processing loc:  43903
# Processing loc:  44539
# Processing loc:  44540
# Processing loc:  43940
# Processing loc:  43904
# Processing loc:  43941
# Processing loc:  43905
# Processing loc:  43942
# Processing loc:  43906
# Processing loc:  164
# Processing loc:  165
# Processing loc:  491
# Processing loc:  492
# Processing loc:  493
# Processing loc:  494
# Processing loc:  495
# Processing loc:  496
# Processing loc:  497
# Processing loc:  498
# Processing loc:  499
# Processing loc:  500
# Processing loc:  501
# Processing loc:  502
# Processing loc:  354
# Processing loc:  503
# Processing loc:  504
# Processing loc:  505
# Processing loc:  506
# Processing loc:  507
# Processing loc:  508
# Processing loc:  509
# Processing loc:  361
# Processing loc:  510
# Processing loc:  511
# Processing loc:  512
# Processing loc:  513
# Processing loc:  514
# Processing loc:  515
# Processing loc:  516
# Processing loc:  517
# Processing loc:  518
# Processing loc:  519
# Processing loc:  520
# Processing loc:  521
# Processing loc:  7
# Processing loc:  8
# Processing loc:  298
# Processing loc:  25
# Processing loc:  22
# Processing loc:  351
# Processing loc:  23
# Processing loc:  24
# Processing loc:  376
# Processing loc:  26
# Processing loc:  27
# Processing loc:  28
# Processing loc:  29
# Processing loc:  30
# Processing loc:  10
# Processing loc:  4709
# Processing loc:  4726
# Processing loc:  4717
# Processing loc:  4725
# Processing loc:  4715
# Processing loc:  4737
# Processing loc:  4720
# Processing loc:  4713
# Processing loc:  4721
# Processing loc:  4722
# Processing loc:  4724
# Processing loc:  4729
# Processing loc:  4731
# Processing loc:  4730
# Processing loc:  4732
# Processing loc:  4719
# Processing loc:  4718
# Processing loc:  4716
# Processing loc:  4739
# Processing loc:  4740
# Processing loc:  4727
# Processing loc:  4728
# Processing loc:  4742
# Processing loc:  4741
# Processing loc:  4712
# Processing loc:  4738
# Processing loc:  4735
# Processing loc:  4734
# Processing loc:  4736
# Processing loc:  4733
# Processing loc:  4711
# Processing loc:  4714
# Processing loc:  4710
# Processing loc:  4723
# Processing loc:  12
# Processing loc:  13
# Processing loc:  14
# Processing loc:  183
# Processing loc:  15
# Processing loc:  16
# Processing loc:  17
# Processing loc:  186
# Processing loc:  18
# Processing loc:  19
# Processing loc:  20
# Processing loc:  168
# Processing loc:  169
# Processing loc:  170
# Processing loc:  171
# Processing loc:  172
# Processing loc:  173
# Processing loc:  175
# Processing loc:  176
# Processing loc:  177
# Processing loc:  178
# Processing loc:  44861
# Processing loc:  44853
# Processing loc:  44854
# Processing loc:  44857
# Processing loc:  44862
# Processing loc:  44860
# Processing loc:  44859
# Processing loc:  44855
# Processing loc:  44856
# Processing loc:  44858
# Processing loc:  44852
# Processing loc:  35617
# Processing loc:  35618
# Processing loc:  35619
# Processing loc:  35620
# Processing loc:  35621
# Processing loc:  35622
# Processing loc:  35623
# Processing loc:  35624
# Processing loc:  35625
# Processing loc:  35626
# Processing loc:  35627
# Processing loc:  35628
# Processing loc:  35629
# Processing loc:  35630
# Processing loc:  35631
# Processing loc:  35632
# Processing loc:  35633
# Processing loc:  35634
# Processing loc:  35635
# Processing loc:  35636
# Processing loc:  35637
# Processing loc:  35638
# Processing loc:  35639
# Processing loc:  35640
# Processing loc:  35641
# Processing loc:  35642
# Processing loc:  35643
# Processing loc:  35644
# Processing loc:  35645
# Processing loc:  35646
# Processing loc:  35647
# Processing loc:  35648
# Processing loc:  35649
# Processing loc:  35650
# Processing loc:  35651
# Processing loc:  35652
# Processing loc:  35653
# Processing loc:  35654
# Processing loc:  35655
# Processing loc:  35656
# Processing loc:  35657
# Processing loc:  35658
# Processing loc:  35659
# Processing loc:  35660
# Processing loc:  35661
# Processing loc:  35662
# Processing loc:  35663
# Processing loc:  181
# Processing loc:  182
# Processing loc:  184
# Processing loc:  185
# Processing loc:  187
# Processing loc:  435
# Processing loc:  189
# Processing loc:  190
# Processing loc:  191
# Processing loc:  193
# Processing loc:  194
# Processing loc:  195
# Processing loc:  482
# Processing loc:  483
# Processing loc:  484
# Processing loc:  485
# Processing loc:  486
# Processing loc:  487
# Processing loc:  488
# Processing loc:  489
# Processing loc:  490
# Processing loc:  197
# Processing loc:  198
# Processing loc:  200
# Processing loc:  201
# Processing loc:  202
# Processing loc:  203
# Processing loc:  204
# Processing loc:  205
# Processing loc:  206
# Processing loc:  207
# Processing loc:  208
# Processing loc:  209
# Processing loc:  210
# Processing loc:  211
# Processing loc:  212
# Processing loc:  213
# Processing loc:  214
# Processing loc:  215
# Processing loc:  216
# Processing loc:  217
# Processing loc:  218
# Saving to  /share/scratch/projects/hssa/haq/HAQ_2017/haq_US/combined_data/global_data/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# ...
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# <ipython-input-22-6edc4f3959e9> in <module>
#      17
#      18 print("Saving to ", my_data_dir+'combined_data/global_data/')
# ---> 19 allMostDet_data_noncancer.to_csv(my_data_dir+'combined_data/global_data/' + 'allMostDet_data_noncancer.csv',index=False)
#      20
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    3018                                  doublequote=doublequote,
#    3019                                  escapechar=escapechar, decimal=decimal)
# -> 3020         formatter.save()
#    3021
#    3022         if path_or_buf is None:
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/io/formats/csvs.py in save(self)
#     170                 self.writer = UnicodeWriter(f, **writer_kwargs)
#     171
# --> 172             self._save()
#     173
#     174         finally:
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/io/formats/csvs.py in _save(self)
#     286                 break
#     287
# --> 288             self._save_chunk(start_i, end_i)
#     289
#     290     def _save_chunk(self, start_i, end_i):
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/io/formats/csvs.py in _save_chunk(self, start_i, end_i)
#     300                                   decimal=self.decimal,
#     301                                   date_format=self.date_format,
# --> 302                                   quoting=self.quoting)
#     303
#     304             for col_loc, col in zip(b.mgr_locs, d):
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in to_native_types(self, slicer, na_rep, quoting, **kwargs)
#     739
#     740         if not self.is_object and not quoting:
# --> 741             values = values.astype(str)
#     742         else:
#     743             values = np.array(values, dtype='object')
#
# SystemError: <built-in method item of numpy.ndarray object at 0x2b7efee4ac60> returned a result with an error set

# %%
allMostDet_data_noncancer.head()
# Out:
#    location_id  year_id  age_group_id  sex_id  cause_id  draw     rsval  \
# 0           33     2016             2       3       302     0  0.000301
# 1           33     2016             2       3       302     1  0.000246
# 2           33     2016             2       3       302     2  0.000272
# 3           33     2016             2       3       302     3  0.000266
# 4           33     2016             2       3       302     4  0.000231
#
#         val
# 0  0.000301
# 1  0.000246
# 2  0.000272
# 3  0.000266
# 4  0.000231

# %%
allMostDet_data_noncancer.to_csv(my_data_dir+'combined_data/global_data/' + 'allMostDet_data_noncancer.csv',index=False)

# %%
my_data_dir_cancer = '/share/scratch/projects/hssa/haq/HAQ_2017/haq_2017_latest_cancer/cancers_all_most_det_locs/'
allMostDet_data_cancer =[]
for y in years:
    print('Processing: ',y)
    for i in list(most_det_locs):
        print('Processing loc: ',i)
        df = pd.read_csv(my_data_dir_cancer+str(y)+'/'+str(i)+'.csv')
        # keeping only cancer
        df = df[df['cause_id'].isin([849, 429, 432, 435, 441, 468, 484, 487])]
        
        df = df.merge(cause_limits,on='cause_id')
        df = df[(df['age_group_id'] >= df['age_start'])&(df['age_group_id'] <= df['age_end'])]
        df = df.drop(['age_end','age_start'],axis=1)
        
        allMostDet_data_cancer.append(df)
allMostDet_data_cancer = pd.concat(allMostDet_data_cancer, axis=0)

print("Saving to ", my_data_dir+'combined_data/global_data/')
allMostDet_data_cancer.to_csv(my_data_dir+'combined_data/global_data/' + 'allMostDet_data_cancer.csv',index=False)
# Out:
# Processing:  2016
# Processing loc:  33
# Processing loc:  34
# Processing loc:  35
# Processing loc:  36
# Processing loc:  37
# Processing loc:  38
# Processing loc:  39
# Processing loc:  40
# Processing loc:  41
# Processing loc:  43
# Processing loc:  44
# Processing loc:  45
# Processing loc:  46
# Processing loc:  47
# Processing loc:  48
# Processing loc:  49
# Processing loc:  50
# Processing loc:  51
# Processing loc:  52
# Processing loc:  53
# Processing loc:  54
# Processing loc:  55
# Processing loc:  57
# Processing loc:  58
# Processing loc:  59
# Processing loc:  60
# Processing loc:  61
# Processing loc:  44971
# Processing loc:  44983
# Processing loc:  44924
# Processing loc:  44936
# Processing loc:  44903
# Processing loc:  44904
# Processing loc:  44945
# Processing loc:  44966
# Processing loc:  44987
# Processing loc:  44952
# Processing loc:  44974
# Processing loc:  44907
# Processing loc:  44986
# Processing loc:  44942
# Processing loc:  44926
# Processing loc:  44908
# Processing loc:  44980
# Processing loc:  44943
# Processing loc:  44975
# Processing loc:  44982
# Processing loc:  44963
# Processing loc:  44954
# Processing loc:  44922
# Processing loc:  44909
# Processing loc:  44935
# Processing loc:  44973
# Processing loc:  44961
# Processing loc:  44910
# Processing loc:  44927
# Processing loc:  44911
# Processing loc:  44984
# Processing loc:  44920
# Processing loc:  44912
# Processing loc:  44928
# Processing loc:  44923
# Processing loc:  44955
# Processing loc:  44929
# Processing loc:  44976
# Processing loc:  44977
# Processing loc:  44956
# Processing loc:  44913
# Processing loc:  44957
# Processing loc:  44953
# Processing loc:  44981
# Processing loc:  44930
# Processing loc:  44932
# Processing loc:  44967
# Processing loc:  44947
# Processing loc:  44968
# Processing loc:  44940
# Processing loc:  44941
# Processing loc:  44933
# Processing loc:  44921
# Processing loc:  44970
# Processing loc:  44948
# Processing loc:  44949
# Processing loc:  44944
# Processing loc:  44979
# Processing loc:  44950
# Processing loc:  44969
# Processing loc:  44938
# Processing loc:  44914
# Processing loc:  44985
# Processing loc:  44958
# Processing loc:  44931
# Processing loc:  44959
# Processing loc:  44915
# Processing loc:  44946
# Processing loc:  44962
# Processing loc:  44916
# Processing loc:  44978
# Processing loc:  44918
# Processing loc:  44917
# Processing loc:  44965
# Processing loc:  44951
# Processing loc:  44960
# Processing loc:  44905
# Processing loc:  44937
# Processing loc:  44925
# Processing loc:  44906
# Processing loc:  44964
# Processing loc:  44919
# Processing loc:  44972
# Processing loc:  44934
# Processing loc:  44939
# Processing loc:  50559
# Processing loc:  71
# Processing loc:  44850
# Processing loc:  44851
# Processing loc:  66
# Processing loc:  35446
# Processing loc:  35428
# Processing loc:  35425
# Processing loc:  35435
# Processing loc:  35461
# Processing loc:  35441
# Processing loc:  35463
# Processing loc:  35430
# Processing loc:  35444
# Processing loc:  35433
# Processing loc:  35457
# Processing loc:  35424
# Processing loc:  35451
# Processing loc:  35431
# Processing loc:  35440
# Processing loc:  35426
# Processing loc:  35460
# Processing loc:  35469
# Processing loc:  35437
# Processing loc:  35462
# Processing loc:  35466
# Processing loc:  35449
# Processing loc:  35447
# Processing loc:  35427
# Processing loc:  35468
# Processing loc:  35443
# Processing loc:  35465
# Processing loc:  35452
# Processing loc:  35438
# Processing loc:  35467
# Processing loc:  35456
# Processing loc:  35470
# Processing loc:  35450
# Processing loc:  35464
# Processing loc:  35434
# Processing loc:  35448
# Processing loc:  35455
# Processing loc:  35445
# Processing loc:  35432
# Processing loc:  35459
# Processing loc:  35436
# Processing loc:  35454
# Processing loc:  35439
# Processing loc:  35453
# Processing loc:  35429
# Processing loc:  35458
# Processing loc:  35442
# Processing loc:  68
# Processing loc:  69
# Processing loc:  101
# Processing loc:  349
# Processing loc:  523
# Processing loc:  524
# Processing loc:  525
# Processing loc:  526
# Processing loc:  527
# Processing loc:  528
# Processing loc:  529
# Processing loc:  530
# Processing loc:  531
# Processing loc:  532
# Processing loc:  533
# Processing loc:  534
# Processing loc:  535
# Processing loc:  536
# Processing loc:  537
# Processing loc:  538
# Processing loc:  539
# Processing loc:  540
# Processing loc:  541
# Processing loc:  542
# Processing loc:  543
# Processing loc:  544
# Processing loc:  545
# Processing loc:  546
# Processing loc:  547
# Processing loc:  548
# Processing loc:  549
# Processing loc:  550
# Processing loc:  551
# Processing loc:  552
# Processing loc:  553
# Processing loc:  554
# Processing loc:  555
# Processing loc:  556
# Processing loc:  557
# Processing loc:  558
# Processing loc:  559
# Processing loc:  560
# Processing loc:  561
# Processing loc:  562
# Processing loc:  563
# Processing loc:  564
# Processing loc:  565
# Processing loc:  566
# Processing loc:  567
# Processing loc:  568
# Processing loc:  569
# Processing loc:  570
# Processing loc:  571
# Processing loc:  572
# Processing loc:  573
# Processing loc:  97
# Processing loc:  98
# Processing loc:  99
# Processing loc:  74
# Processing loc:  75
# Processing loc:  76
# Processing loc:  77
# Processing loc:  78
# Processing loc:  79
# Processing loc:  80
# Processing loc:  81
# Processing loc:  82
# Processing loc:  83
# Processing loc:  84
# Processing loc:  85
# Processing loc:  86
# Processing loc:  87
# Processing loc:  88
# Processing loc:  89
# Processing loc:  4914
# Processing loc:  4911
# Processing loc:  4918
# Processing loc:  4915
# Processing loc:  4928
# Processing loc:  4912
# Processing loc:  4921
# Processing loc:  4923
# Processing loc:  4926
# Processing loc:  4913
# Processing loc:  4910
# Processing loc:  4920
# Processing loc:  4922
# Processing loc:  4917
# Processing loc:  53432
# Processing loc:  4927
# Processing loc:  4919
# Processing loc:  4916
# Processing loc:  91
# Processing loc:  92
# Processing loc:  4944
# Processing loc:  4940
# Processing loc:  94
# Processing loc:  44697
# Processing loc:  44698
# Processing loc:  44701
# Processing loc:  44694
# Processing loc:  44695
# Processing loc:  44693
# Processing loc:  44700
# Processing loc:  44699
# Processing loc:  44696
# Processing loc:  44716
# Processing loc:  44721
# Processing loc:  44717
# Processing loc:  44720
# Processing loc:  44719
# Processing loc:  44726
# Processing loc:  44723
# Processing loc:  44725
# Processing loc:  44724
# Processing loc:  44718
# Processing loc:  44722
# Processing loc:  44754
# Processing loc:  44729
# Processing loc:  44732
# Processing loc:  44735
# Processing loc:  44731
# Processing loc:  44748
# Processing loc:  44742
# Processing loc:  44744
# Processing loc:  44741
# Processing loc:  44745
# Processing loc:  44756
# Processing loc:  44743
# Processing loc:  44755
# Processing loc:  44740
# Processing loc:  44737
# Processing loc:  44736
# Processing loc:  44751
# Processing loc:  44757
# Processing loc:  44728
# Processing loc:  44738
# Processing loc:  44749
# Processing loc:  44750
# Processing loc:  44734
# Processing loc:  44753
# Processing loc:  44733
# Processing loc:  44727
# Processing loc:  44752
# Processing loc:  44739
# Processing loc:  44758
# Processing loc:  44747
# Processing loc:  44746
# Processing loc:  44730
# Processing loc:  44649
# Processing loc:  44643
# Processing loc:  44650
# Processing loc:  44654
# Processing loc:  44651
# Processing loc:  44646
# Processing loc:  44647
# Processing loc:  44644
# Processing loc:  44648
# Processing loc:  44652
# Processing loc:  44645
# Processing loc:  44653
# Processing loc:  44674
# Processing loc:  44676
# Processing loc:  44662
# Processing loc:  44664
# Processing loc:  44655
# Processing loc:  44658
# Processing loc:  44661
# Processing loc:  44670
# Processing loc:  44675
# Processing loc:  44660
# Processing loc:  44671
# Processing loc:  44677
# Processing loc:  44667
# Processing loc:  44668
# Processing loc:  44673
# Processing loc:  44659
# Processing loc:  44665
# Processing loc:  44656
# Processing loc:  44672
# Processing loc:  44657
# Processing loc:  44666
# Processing loc:  44669
# Processing loc:  44663
# Processing loc:  44765
# Processing loc:  44770
# Processing loc:  44760
# Processing loc:  44772
# Processing loc:  44764
# Processing loc:  44774
# Processing loc:  44769
# Processing loc:  44771
# Processing loc:  44775
# Processing loc:  44767
# Processing loc:  44773
# Processing loc:  44768
# Processing loc:  44777
# Processing loc:  44776
# Processing loc:  44761
# Processing loc:  44763
# Processing loc:  44766
# Processing loc:  44762
# Processing loc:  44759
# Processing loc:  44784
# Processing loc:  44790
# Processing loc:  44789
# Processing loc:  44791
# Processing loc:  44782
# Processing loc:  44779
# Processing loc:  44785
# Processing loc:  44781
# Processing loc:  44792
# Processing loc:  44783
# Processing loc:  44786
# Processing loc:  44778
# Processing loc:  44787
# Processing loc:  44788
# Processing loc:  44780
# Processing loc:  44714
# Processing loc:  44709
# Processing loc:  44708
# Processing loc:  44703
# Processing loc:  44715
# Processing loc:  44705
# Processing loc:  44704
# Processing loc:  44707
# Processing loc:  44711
# Processing loc:  44710
# Processing loc:  44712
# Processing loc:  44702
# Processing loc:  44713
# Processing loc:  44706
# Processing loc:  44692
# Processing loc:  44684
# Processing loc:  44682
# Processing loc:  44690
# Processing loc:  44679
# Processing loc:  44691
# Processing loc:  44685
# Processing loc:  44686
# Processing loc:  44681
# Processing loc:  44683
# Processing loc:  44678
# Processing loc:  44689
# Processing loc:  44687
# Processing loc:  44688
# Processing loc:  44680
# Processing loc:  433
# Processing loc:  434
# Processing loc:  4636
# Processing loc:  121
# Processing loc:  122
# Processing loc:  123
# Processing loc:  105
# Processing loc:  106
# Processing loc:  107
# Processing loc:  108
# Processing loc:  305
# Processing loc:  109
# Processing loc:  110
# Processing loc:  111
# Processing loc:  112
# Processing loc:  113
# Processing loc:  114
# Processing loc:  115
# Processing loc:  385
# Processing loc:  116
# Processing loc:  117
# Processing loc:  118
# Processing loc:  119
# Processing loc:  422
# Processing loc:  125
# Processing loc:  126
# Processing loc:  127
# Processing loc:  128
# Processing loc:  129
# Processing loc:  4643
# Processing loc:  4644
# Processing loc:  4645
# Processing loc:  4646
# Processing loc:  4649
# Processing loc:  4650
# Processing loc:  4647
# Processing loc:  4648
# Processing loc:  4652
# Processing loc:  4653
# Processing loc:  4654
# Processing loc:  4655
# Processing loc:  4656
# Processing loc:  4657
# Processing loc:  4651
# Processing loc:  4658
# Processing loc:  4659
# Processing loc:  4660
# Processing loc:  4661
# Processing loc:  4662
# Processing loc:  4663
# Processing loc:  4664
# Processing loc:  4665
# Processing loc:  4666
# Processing loc:  4667
# Processing loc:  4668
# Processing loc:  4669
# Processing loc:  4670
# Processing loc:  4671
# Processing loc:  4672
# Processing loc:  4673
# Processing loc:  4674
# Processing loc:  131
# Processing loc:  132
# Processing loc:  133
# Processing loc:  4750
# Processing loc:  4751
# Processing loc:  4753
# Processing loc:  4752
# Processing loc:  4754
# Processing loc:  4755
# Processing loc:  4756
# Processing loc:  4757
# Processing loc:  4758
# Processing loc:  4759
# Processing loc:  4762
# Processing loc:  4761
# Processing loc:  4760
# Processing loc:  4763
# Processing loc:  4764
# Processing loc:  4765
# Processing loc:  4766
# Processing loc:  4767
# Processing loc:  4768
# Processing loc:  4769
# Processing loc:  4772
# Processing loc:  4770
# Processing loc:  4771
# Processing loc:  4773
# Processing loc:  4775
# Processing loc:  4774
# Processing loc:  4776
# Processing loc:  136
# Processing loc:  160
# Processing loc:  139
# Processing loc:  140
# Processing loc:  141
# Processing loc:  44864
# Processing loc:  44865
# Processing loc:  44868
# Processing loc:  44869
# Processing loc:  44866
# Processing loc:  44870
# Processing loc:  44871
# Processing loc:  44872
# Processing loc:  44873
# Processing loc:  44874
# Processing loc:  44875
# Processing loc:  44876
# Processing loc:  44877
# Processing loc:  44878
# Processing loc:  44880
# Processing loc:  44882
# Processing loc:  44883
# Processing loc:  44884
# Processing loc:  44885
# Processing loc:  44886
# Processing loc:  44887
# Processing loc:  44879
# Processing loc:  44888
# Processing loc:  44889
# Processing loc:  44890
# Processing loc:  44891
# Processing loc:  44881
# Processing loc:  44892
# Processing loc:  44867
# Processing loc:  44893
# Processing loc:  44894
# Processing loc:  143
# Processing loc:  144
# Processing loc:  145
# Processing loc:  146
# Processing loc:  147
# Processing loc:  148
# Processing loc:  149
# Processing loc:  150
# Processing loc:  151
# Processing loc:  152
# Processing loc:  522
# Processing loc:  153
# Processing loc:  154
# Processing loc:  155
# Processing loc:  156
# Processing loc:  157
# Processing loc:  161
# Processing loc:  162
# Processing loc:  43908
# Processing loc:  43872
# Processing loc:  43909
# Processing loc:  43873
# Processing loc:  43910
# Processing loc:  43874
# Processing loc:  43911
# Processing loc:  43875
# Processing loc:  43913
# Processing loc:  43877
# Processing loc:  43916
# Processing loc:  43880
# Processing loc:  43917
# Processing loc:  43881
# Processing loc:  43918
# Processing loc:  43882
# Processing loc:  43919
# Processing loc:  43883
# Processing loc:  43920
# Processing loc:  43884
# Processing loc:  43921
# Processing loc:  43885
# Processing loc:  43922
# Processing loc:  43886
# Processing loc:  43923
# Processing loc:  43887
# Processing loc:  43924
# Processing loc:  43888
# Processing loc:  43926
# Processing loc:  43890
# Processing loc:  43927
# Processing loc:  43891
# Processing loc:  43928
# Processing loc:  43892
# Processing loc:  43929
# Processing loc:  43893
# Processing loc:  43930
# Processing loc:  43894
# Processing loc:  43931
# Processing loc:  43895
# Processing loc:  43932
# Processing loc:  43896
# Processing loc:  43934
# Processing loc:  43898
# Processing loc:  43935
# Processing loc:  43899
# Processing loc:  43936
# Processing loc:  43900
# Processing loc:  43937
# Processing loc:  43901
# Processing loc:  43938
# Processing loc:  43902
# Processing loc:  43939
# Processing loc:  43903
# Processing loc:  44539
# Processing loc:  44540
# Processing loc:  43940
# Processing loc:  43904
# Processing loc:  43941
# Processing loc:  43905
# Processing loc:  43942
# Processing loc:  43906
# Processing loc:  164
# Processing loc:  165
# Processing loc:  491
# Processing loc:  492
# Processing loc:  493
# Processing loc:  494
# Processing loc:  495
# Processing loc:  496
# Processing loc:  497
# Processing loc:  498
# Processing loc:  499
# Processing loc:  500
# Processing loc:  501
# Processing loc:  502
# Processing loc:  354
# Processing loc:  503
# Processing loc:  504
# Processing loc:  505
# Processing loc:  506
# Processing loc:  507
# Processing loc:  508
# Processing loc:  509
# Processing loc:  361
# Processing loc:  510
# Processing loc:  511
# Processing loc:  512
# Processing loc:  513
# Processing loc:  514
# Processing loc:  515
# Processing loc:  516
# Processing loc:  517
# Processing loc:  518
# Processing loc:  519
# Processing loc:  520
# Processing loc:  521
# Processing loc:  7
# Processing loc:  8
# Processing loc:  298
# Processing loc:  25
# Processing loc:  22
# Processing loc:  351
# Processing loc:  23
# Processing loc:  24
# Processing loc:  376
# Processing loc:  26
# Processing loc:  27
# Processing loc:  28
# Processing loc:  29
# Processing loc:  30
# Processing loc:  10
# Processing loc:  4709
# Processing loc:  4726
# Processing loc:  4717
# Processing loc:  4725
# Processing loc:  4715
# Processing loc:  4737
# Processing loc:  4720
# Processing loc:  4713
# Processing loc:  4721
# Processing loc:  4722
# Processing loc:  4724
# Processing loc:  4729
# Processing loc:  4731
# Processing loc:  4730
# Processing loc:  4732
# Processing loc:  4719
# Processing loc:  4718
# Processing loc:  4716
# Processing loc:  4739
# Processing loc:  4740
# Processing loc:  4727
# Processing loc:  4728
# Processing loc:  4742
# Processing loc:  4741
# Processing loc:  4712
# Processing loc:  4738
# Processing loc:  4735
# Processing loc:  4734
# Processing loc:  4736
# Processing loc:  4733
# Processing loc:  4711
# Processing loc:  4714
# Processing loc:  4710
# Processing loc:  4723
# Processing loc:  12
# Processing loc:  13
# Processing loc:  14
# Processing loc:  183
# Processing loc:  15
# Processing loc:  16
# Processing loc:  17
# Processing loc:  186
# Processing loc:  18
# Processing loc:  19
# Processing loc:  20
# Processing loc:  168
# Processing loc:  169
# Processing loc:  170
# Processing loc:  171
# Processing loc:  172
# Processing loc:  173
# Processing loc:  175
# Processing loc:  176
# Processing loc:  177
# Processing loc:  178
# Processing loc:  44861
# Processing loc:  44853
# Processing loc:  44854
# Processing loc:  44857
# Processing loc:  44862
# Processing loc:  44860
# Processing loc:  44859
# Processing loc:  44855
# Processing loc:  44856
# Processing loc:  44858
# Processing loc:  44852
# Processing loc:  35617
# Processing loc:  35618
# Processing loc:  35619
# Processing loc:  35620
# Processing loc:  35621
# Processing loc:  35622
# Processing loc:  35623
# Processing loc:  35624
# Processing loc:  35625
# Processing loc:  35626
# Processing loc:  35627
# Processing loc:  35628
# Processing loc:  35629
# Processing loc:  35630
# Processing loc:  35631
# Processing loc:  35632
# Processing loc:  35633
# Processing loc:  35634
# Processing loc:  35635
# Processing loc:  35636
# Processing loc:  35637
# Processing loc:  35638
# Processing loc:  35639
# Processing loc:  35640
# Processing loc:  35641
# Processing loc:  35642
# Processing loc:  35643
# Processing loc:  35644
# Processing loc:  35645
# Processing loc:  35646
# Processing loc:  35647
# Processing loc:  35648
# Processing loc:  35649
# Processing loc:  35650
# Processing loc:  35651
# Processing loc:  35652
# Processing loc:  35653
# Processing loc:  35654
# Processing loc:  35655
# Processing loc:  35656
# Processing loc:  35657
# Processing loc:  35658
# Processing loc:  35659
# Processing loc:  35660
# Processing loc:  35661
# Processing loc:  35662
# Processing loc:  35663
# Processing loc:  181
# Processing loc:  182
# Processing loc:  184
# Processing loc:  185
# Processing loc:  187
# Processing loc:  435
# Processing loc:  189
# Processing loc:  190
# Processing loc:  191
# Processing loc:  193
# Processing loc:  194
# Processing loc:  195
# Processing loc:  482
# Processing loc:  483
# Processing loc:  484
# Processing loc:  485
# Processing loc:  486
# Processing loc:  487
# Processing loc:  488
# Processing loc:  489
# Processing loc:  490
# Processing loc:  197
# Processing loc:  198
# Processing loc:  200
# Processing loc:  201
# Processing loc:  202
# Processing loc:  203
# Processing loc:  204
# Processing loc:  205
# Processing loc:  206
# Processing loc:  207
# Processing loc:  208
# Processing loc:  209
# Processing loc:  210
# Processing loc:  211
# Processing loc:  212
# Processing loc:  213
# Processing loc:  214
# Processing loc:  215
# Processing loc:  216
# Processing loc:  217
# Processing loc:  218
# Saving to  /share/scratch/projects/hssa/haq/HAQ_2017/haq_US/combined_data/global_data/

# %%
peer_data_noncancer.cause_id.nunique()
